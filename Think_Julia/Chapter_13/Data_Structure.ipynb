# %%
line = "  This is, new! line of code  ? "


#line = replace(line, r"[[:punct:]]" => "")
line = strip(replace(line, r"[[:punct:]]" => ""))

a = collect(split(line, " "))
# Out:
# 6-element Vector{SubString{String}}:
#  "This"
#  "is"
#  "new"
#  "line"
#  "of"
#  "code"

# %%
a
# Out:
# 6-element Vector{SubString{String}}:
#  "This"
#  "is"
#  "new"
#  "line"
#  "of"
#  "code"

# %%
typeof(a)
# Out:
# Vector{SubString{String}} (alias for Array{SubString{String}, 1})

# %%
text = "Hello, world! Welcome to Julia."
clean_text = replace(text, r"[[:punct:]]" => "")  # Removes all punctuation
# Result: "Hello world Welcome to Julia"
# Out:
# "Hello world Welcome to Julia"

# %%
function isletter(a)
    word_dict = Dict()
    counter = 0
    for line in eachline(a)
        line =lowercase(line)
        line = strip(replace(line, r"[[:punct:]]" => ""))
        line_words = collect(split(line))

        for word in line_words
            counter +=1
            if word ∉ keys(word_dict)
                word_dict[word] = 1
            else
                word_dict[word] +=1
            end
        end
    end
    distinct_words = length(word_dict)
    println(word_dict)
    println("The total number of words in the file is: $counter")
    println("The total number of distinct words is: $distinct_words")
end
# Out:
# isletter (generic function with 1 method)

# %%
a = ("Shakespeare.txt")

isletter(a)
# Out:
# Dict{Any, Any}("baleful" => 7, "oblique" => 1, "ungoverned" => 4, "wentand" => 1, "warworn" => 1, "frowning" => 17, "onioneyed" => 1, "waterflies" => 2, "timepleaser" => 1, "overveild" => 1, "gout" => 8, "propositions" => 1, "henry" => 627, "barkd" => 1, "228" => 1, "tameness" => 2, "entomb" => 3, "rises" => 25, "darkworking" => 1, "unwholesome" => 10, "redresses" => 2, "progression" => 1, "stirrers" => 1, "tribunal" => 2, "il" => 9, "knots" => 9, "precor" => 1, "dutys" => 1, "gathered" => 8, "mewed" => 3, "lovers" => 88, "emptyhearted" => 1, "561" => 1, "goads" => 1, "underground" => 2, "oernight" => 1, "leapinghouses" => 1, "longd" => 1, "caught" => 32, "lafew" => 118, "malvolios" => 4, "obey" => 81, "methods" => 2, "sinons" => 3, "duppd" => 1, "annals" => 1, "blithild" => 1, "112" => 2, "torturd" => 2, "englutted" => 2, "everburning" => 2, "relenteth" => 1, "plentiful" => 4, "proportioned" => 2, "gaultree" => 3, "benchholes" => 1, "braided" => 2, "snowball" => 1, "fountain" => 17, "crib" => 1, "sallies" => 1, "eighteen" => 7, "thassos" => 1, "jolthead" => 1, "fleshfly" => 1, "walleyd" => 1, "steadfastly" => 1, "chough" => 3, "himthough" => 1, "incursions" => 2, "grated" => 2, "ungrateful" => 7, "unsalted" => 1, "silk" => 22, "graveless" => 1, "didos" => 2, "purposed" => 11, "simulation" => 1, "gay" => 11, "pails" => 1, "pot" => 14, "gratulate" => 4, "forester" => 12, "replacement" => 5, "reverence" => 45, "a" => 16357, "ladiesand" => 1, "fetching" => 1, "difficile" => 1, "advice" => 50, "commandment" => 15, "sanity" => 1, "stories" => 9, "soulkilling" => 1, "coal" => 11, "searched" => 4, "wrongd" => 15, "exclaim" => 11, "remedies" => 9, "particular" => 56, "shouting" => 5, "paler" => 4, "regarded" => 7, "tooth" => 23, "walkd" => 12, "viceroy" => 2, "unhousled" => 1, "behavedst" => 1, "brighten" => 1, "compromisd" => 1, "redeemd" => 4, "undisposd" => 1, "carnal" => 3, "feodary" => 1, "testy" => 9, "bathe" => 7, "folded" => 8, "friendlucio" => 1, "handsomely" => 3, "trenchant" => 1, "deliciousness" => 1, "exile" => 27, "sumless" => 1, "hume" => 19, "oxen" => 8, "invocations" => 1, "scowl" => 2, "preferrd" => 5, "vanquished" => 11, "discoverd" => 5, "heirapparent" => 3, "unarms" => 1, "languished" => 1, "answers" => 24, "huntsman" => 17, "delicates" => 1, "thaffected" => 1, "suggestion" => 10, "blistered" => 2, "witnessd" => 2, "revengingly" => 1, "gashd" => 1, "toiling" => 2, "plood" => 1, "champaigne" => 1, "biancas" => 6, "unbounded" => 2, "rosemary" => 7, "117" => 1, "purchases" => 1, "adorned" => 2, "bulwarks" => 4, "prides" => 1, "usthou" => 1, "commodities" => 3, "hissing" => 3, "mortally" => 3, "robes" => 20, "discolourd" => 2, "nowwhat" => 2, "trusted" => 11, "rob" => 39, "concerneth" => 1, "uphold" => 6, "followst" => 1, "joymust" => 1, "tullius" => 1, "mori" => 1, "unload" => 2, "moorfields" => 1, "necessaries" => 7, "judges" => 13, "unions" => 1, "parthia" => 7, "spoon" => 4, "instinct" => 16, "overtedious" => 1, "persian" => 2, "undo" => 32, "travailed" => 1, "embers" => 2, "swearer" => 1, "heaping" => 2, "incantations" => 1, "pauser" => 1, "priestess" => 1, "tasteful" => 1, "warlike" => 65, "hind" => 13, "handmaids" => 2, "affirmation" => 1, "loam" => 5, "basan" => 1, "unwittingly" => 2, "lineaments" => 7, "chaff" => 10, "official" => 4, "allfeared" => 1, "main" => 52, "bewailing" => 1, "sear" => 4, "gardenyea" => 1, "earlsnay" => 1, "every" => 506, "palaces" => 7, "conycatch" => 1, "helper" => 2, "earn" => 6, "menacing" => 1, "fearing" => 30, "swoon" => 15, "albeit" => 16, "wellborn" => 1, "amphimacus" => 1, "moai" => 4, "magnanimous" => 7, "fellies" => 1, "comforter" => 5, "pratst" => 3, "signified" => 3, "downgive" => 1, "bide" => 16, "pastoralcomical" => 1, "savagewild" => 1, "divest" => 2, "windi" => 1, "purchasd" => 4, "bergomask" => 2, "lesser" => 32, "team" => 7, "craftier" => 1, "alexascome" => 1, "blusters" => 1, "attacks" => 1, "roaming" => 3, "misprision" => 7, "damsons" => 1, "nell" => 15, "deluge" = ...
# The total number of words in the file is: 966372
# The total number of distinct words is: 30532

# %%
line_words = ["name" "class" "place" "address" "class" "name" "school" "class"]
counter = 0

word_dict = Dict()

for word in line_words
    counter +=1
    if word ∉ keys(word_dict)
        word_dict[word] = 1
    else
        word_dict[word] +=1
    end
end
println(word_dict)
println(counter)
println(length(word_dict))
# Out:
# Dict{Any, Any}("name" => 2, "place" => 1, "class" => 3, "school" => 1, "address" => 1)
# 8
# 5

# %% [markdown]
# ## Exercise 13-3
#
# Modify the program from the previous exercise to print the 20 most frequently used
# words in the book.

# %%
function isletter(a)
    word_dict = Dict()
    counter = 0
    for line in eachline(a)
        line =lowercase(line)
        line = strip(replace(line, r"[[:punct:]]" => ""))
        line_words = collect(split(line))

        for word in line_words
            counter +=1
            if !(word isa Integer) && word isa AbstractString
                if word ∉ keys(word_dict)
                    word_dict[word] = 1
                else
                    word_dict[word] +=1
                end
            end
        end
    end

    highest_key = argmax(word_dict)
    println(word_dict[highest_key])
    distinct_words = length(word_dict)
    println(word_dict)
    println("The total number of words in the file is: $counter")
    println("The total number of distinct words is: $distinct_words")
    
end
# Out:
# isletter (generic function with 1 method)

# %%
a = ("Shakespeare.txt")

isletter(a)
# Out:
# 30550
# Dict{Any, Any}("baleful" => 7, "oblique" => 1, "ungoverned" => 4, "wentand" => 1, "warworn" => 1, "frowning" => 17, "onioneyed" => 1, "waterflies" => 2, "timepleaser" => 1, "overveild" => 1, "gout" => 8, "propositions" => 1, "henry" => 627, "barkd" => 1, "228" => 1, "tameness" => 2, "entomb" => 3, "rises" => 25, "darkworking" => 1, "unwholesome" => 10, "redresses" => 2, "progression" => 1, "stirrers" => 1, "tribunal" => 2, "il" => 9, "knots" => 9, "precor" => 1, "dutys" => 1, "gathered" => 8, "mewed" => 3, "lovers" => 88, "emptyhearted" => 1, "561" => 1, "goads" => 1, "underground" => 2, "oernight" => 1, "leapinghouses" => 1, "longd" => 1, "caught" => 32, "lafew" => 118, "malvolios" => 4, "obey" => 81, "methods" => 2, "sinons" => 3, "duppd" => 1, "annals" => 1, "blithild" => 1, "112" => 2, "torturd" => 2, "englutted" => 2, "everburning" => 2, "relenteth" => 1, "plentiful" => 4, "proportioned" => 2, "gaultree" => 3, "benchholes" => 1, "braided" => 2, "snowball" => 1, "fountain" => 17, "crib" => 1, "sallies" => 1, "eighteen" => 7, "thassos" => 1, "jolthead" => 1, "fleshfly" => 1, "walleyd" => 1, "steadfastly" => 1, "chough" => 3, "himthough" => 1, "incursions" => 2, "grated" => 2, "ungrateful" => 7, "unsalted" => 1, "silk" => 22, "graveless" => 1, "didos" => 2, "purposed" => 11, "simulation" => 1, "gay" => 11, "pails" => 1, "pot" => 14, "gratulate" => 4, "forester" => 12, "replacement" => 5, "reverence" => 45, "a" => 16357, "ladiesand" => 1, "fetching" => 1, "difficile" => 1, "advice" => 50, "commandment" => 15, "sanity" => 1, "stories" => 9, "soulkilling" => 1, "coal" => 11, "searched" => 4, "wrongd" => 15, "exclaim" => 11, "remedies" => 9, "particular" => 56, "shouting" => 5, "paler" => 4, "regarded" => 7, "tooth" => 23, "walkd" => 12, "viceroy" => 2, "unhousled" => 1, "behavedst" => 1, "brighten" => 1, "compromisd" => 1, "redeemd" => 4, "undisposd" => 1, "carnal" => 3, "feodary" => 1, "testy" => 9, "bathe" => 7, "folded" => 8, "friendlucio" => 1, "handsomely" => 3, "trenchant" => 1, "deliciousness" => 1, "exile" => 27, "sumless" => 1, "hume" => 19, "oxen" => 8, "invocations" => 1, "scowl" => 2, "preferrd" => 5, "vanquished" => 11, "discoverd" => 5, "heirapparent" => 3, "unarms" => 1, "languished" => 1, "answers" => 24, "huntsman" => 17, "delicates" => 1, "thaffected" => 1, "suggestion" => 10, "blistered" => 2, "witnessd" => 2, "revengingly" => 1, "gashd" => 1, "toiling" => 2, "plood" => 1, "champaigne" => 1, "biancas" => 6, "unbounded" => 2, "rosemary" => 7, "117" => 1, "purchases" => 1, "adorned" => 2, "bulwarks" => 4, "prides" => 1, "usthou" => 1, "commodities" => 3, "hissing" => 3, "mortally" => 3, "robes" => 20, "discolourd" => 2, "nowwhat" => 2, "trusted" => 11, "rob" => 39, "concerneth" => 1, "uphold" => 6, "followst" => 1, "joymust" => 1, "tullius" => 1, "mori" => 1, "unload" => 2, "moorfields" => 1, "necessaries" => 7, "judges" => 13, "unions" => 1, "parthia" => 7, "spoon" => 4, "instinct" => 16, "overtedious" => 1, "persian" => 2, "undo" => 32, "travailed" => 1, "embers" => 2, "swearer" => 1, "heaping" => 2, "incantations" => 1, "pauser" => 1, "priestess" => 1, "tasteful" => 1, "warlike" => 65, "hind" => 13, "handmaids" => 2, "affirmation" => 1, "loam" => 5, "basan" => 1, "unwittingly" => 2, "lineaments" => 7, "chaff" => 10, "official" => 4, "allfeared" => 1, "main" => 52, "bewailing" => 1, "sear" => 4, "gardenyea" => 1, "earlsnay" => 1, "every" => 506, "palaces" => 7, "conycatch" => 1, "helper" => 2, "earn" => 6, "menacing" => 1, "fearing" => 30, "swoon" => 15, "albeit" => 16, "wellborn" => 1, "amphimacus" => 1, "moai" => 4, "magnanimous" => 7, "fellies" => 1, "comforter" => 5, "pratst" => 3, "signified" => 3, "downgive" => 1, "bide" => 16, "pastoralcomical" => 1, "savagewild" => 1, "divest" => 2, "windi" => 1, "purchasd" => 4, "bergomask" => 2, "lesser" => 32, "team" => 7, "craftier" => 1, "alexascome" => 1, "blusters" => 1, "attacks" => 1, "roaming" => 3, "misprision" => 7, "damsons" => 1, "nell" => 15, "deluge" = ...
# The total number of words in the file is: 966372
# The total number of distinct words is: 30532

# %%
word = 324

if typeof(word) == Int
    
else
    println(word)
end

# %% [markdown]
# ## Random Numbers

# %%
rand()
# Out:
# 0.706453416478184

# %%
for i in 1:10
    x = rand()
    println(x)
end
# Out:
# 0.31488111849812683
# 0.3008903989792482
# 0.3605545110900449
# 0.5550846707929209
# 0.6758970649803004
# 0.4753914094163967
# 0.29095570715560126
# 0.05263503820345006
# 0.8642384104166827
# 0.3717547105408925

# %%
function histogram(s)
    d = Dict()
    for c in s 
        if c ∉ keys(d)
            d[c] = 1
        else
            d[c] +=1
        end
    end
    d
end
# Out:
# histogram (generic function with 1 method)

# %%
t = ['a', 'a', 'b', 'b', 'a', 'g']

a = histogram(t)
# Out:
# Dict{Any, Any} with 3 entries:
#   'g' => 1
#   'a' => 3
#   'b' => 2

# %%
function choosefromhis(a)
    sum_val = 0
    for val in values(a)
        sum_val += val
    end
    
    for vals in values(a)
        println(Rational(vals, sum_val))
    end 
end
# Out:
# choosefromhis (generic function with 1 method)

# %%
choosefromhis(a)
# Out:
# 1//6
# 1//2
# 1//3

# %%
collect("Good")
# Out:
# 4-element Vector{Char}:
#  'G': ASCII/Unicode U+0047 (category Lu: Letter, uppercase)
#  'o': ASCII/Unicode U+006F (category Ll: Letter, lowercase)
#  'o': ASCII/Unicode U+006F (category Ll: Letter, lowercase)
#  'd': ASCII/Unicode U+0064 (category Ll: Letter, lowercase)

# %%
a
# Out:
# Dict{Any, Any} with 3 entries:
#   'g' => 1
#   'a' => 3
#   'b' => 2

# %%
isletter("Shakespeare.txt")
# Out:
# 30550
# Dict{Any, Any}("baleful" => 7, "oblique" => 1, "ungoverned" => 4, "wentand" => 1, "warworn" => 1, "frowning" => 17, "onioneyed" => 1, "waterflies" => 2, "timepleaser" => 1, "overveild" => 1, "gout" => 8, "propositions" => 1, "henry" => 627, "barkd" => 1, "228" => 1, "tameness" => 2, "entomb" => 3, "rises" => 25, "darkworking" => 1, "unwholesome" => 10, "redresses" => 2, "progression" => 1, "stirrers" => 1, "tribunal" => 2, "il" => 9, "knots" => 9, "precor" => 1, "dutys" => 1, "gathered" => 8, "mewed" => 3, "lovers" => 88, "emptyhearted" => 1, "561" => 1, "goads" => 1, "underground" => 2, "oernight" => 1, "leapinghouses" => 1, "longd" => 1, "caught" => 32, "lafew" => 118, "malvolios" => 4, "obey" => 81, "methods" => 2, "sinons" => 3, "duppd" => 1, "annals" => 1, "blithild" => 1, "112" => 2, "torturd" => 2, "englutted" => 2, "everburning" => 2, "relenteth" => 1, "plentiful" => 4, "proportioned" => 2, "gaultree" => 3, "benchholes" => 1, "braided" => 2, "snowball" => 1, "fountain" => 17, "crib" => 1, "sallies" => 1, "eighteen" => 7, "thassos" => 1, "jolthead" => 1, "fleshfly" => 1, "walleyd" => 1, "steadfastly" => 1, "chough" => 3, "himthough" => 1, "incursions" => 2, "grated" => 2, "ungrateful" => 7, "unsalted" => 1, "silk" => 22, "graveless" => 1, "didos" => 2, "purposed" => 11, "simulation" => 1, "gay" => 11, "pails" => 1, "pot" => 14, "gratulate" => 4, "forester" => 12, "replacement" => 5, "reverence" => 45, "a" => 16357, "ladiesand" => 1, "fetching" => 1, "difficile" => 1, "advice" => 50, "commandment" => 15, "sanity" => 1, "stories" => 9, "soulkilling" => 1, "coal" => 11, "searched" => 4, "wrongd" => 15, "exclaim" => 11, "remedies" => 9, "particular" => 56, "shouting" => 5, "paler" => 4, "regarded" => 7, "tooth" => 23, "walkd" => 12, "viceroy" => 2, "unhousled" => 1, "behavedst" => 1, "brighten" => 1, "compromisd" => 1, "redeemd" => 4, "undisposd" => 1, "carnal" => 3, "feodary" => 1, "testy" => 9, "bathe" => 7, "folded" => 8, "friendlucio" => 1, "handsomely" => 3, "trenchant" => 1, "deliciousness" => 1, "exile" => 27, "sumless" => 1, "hume" => 19, "oxen" => 8, "invocations" => 1, "scowl" => 2, "preferrd" => 5, "vanquished" => 11, "discoverd" => 5, "heirapparent" => 3, "unarms" => 1, "languished" => 1, "answers" => 24, "huntsman" => 17, "delicates" => 1, "thaffected" => 1, "suggestion" => 10, "blistered" => 2, "witnessd" => 2, "revengingly" => 1, "gashd" => 1, "toiling" => 2, "plood" => 1, "champaigne" => 1, "biancas" => 6, "unbounded" => 2, "rosemary" => 7, "117" => 1, "purchases" => 1, "adorned" => 2, "bulwarks" => 4, "prides" => 1, "usthou" => 1, "commodities" => 3, "hissing" => 3, "mortally" => 3, "robes" => 20, "discolourd" => 2, "nowwhat" => 2, "trusted" => 11, "rob" => 39, "concerneth" => 1, "uphold" => 6, "followst" => 1, "joymust" => 1, "tullius" => 1, "mori" => 1, "unload" => 2, "moorfields" => 1, "necessaries" => 7, "judges" => 13, "unions" => 1, "parthia" => 7, "spoon" => 4, "instinct" => 16, "overtedious" => 1, "persian" => 2, "undo" => 32, "travailed" => 1, "embers" => 2, "swearer" => 1, "heaping" => 2, "incantations" => 1, "pauser" => 1, "priestess" => 1, "tasteful" => 1, "warlike" => 65, "hind" => 13, "handmaids" => 2, "affirmation" => 1, "loam" => 5, "basan" => 1, "unwittingly" => 2, "lineaments" => 7, "chaff" => 10, "official" => 4, "allfeared" => 1, "main" => 52, "bewailing" => 1, "sear" => 4, "gardenyea" => 1, "earlsnay" => 1, "every" => 506, "palaces" => 7, "conycatch" => 1, "helper" => 2, "earn" => 6, "menacing" => 1, "fearing" => 30, "swoon" => 15, "albeit" => 16, "wellborn" => 1, "amphimacus" => 1, "moai" => 4, "magnanimous" => 7, "fellies" => 1, "comforter" => 5, "pratst" => 3, "signified" => 3, "downgive" => 1, "bide" => 16, "pastoralcomical" => 1, "savagewild" => 1, "divest" => 2, "windi" => 1, "purchasd" => 4, "bergomask" => 2, "lesser" => 32, "team" => 7, "craftier" => 1, "alexascome" => 1, "blusters" => 1, "attacks" => 1, "roaming" => 3, "misprision" => 7, "damsons" => 1, "nell" => 15, "deluge" = ...
# Excessive output truncated after 524289 bytes.
# "better" => 633, "justicer" => 3, "480" => 1, "wheres" => 118, "intricate" => 1, "reach" => 31, "emperors" => 20, "amber" => 7, "inauspicious" => 1, "marroweating" => 1, "lydia" => 2, "irrecoverable" => 1, "bridehouse" => 1, "mouthmade" => 1, "fiveandtwenty" => 8, "crotchets" => 4, "firerobd" => 1, "empirics" => 1, "seldom" => 35, "arrivd" => 17, "assigns" => 2, "foolishly" => 5, "ruinyour" => 1, "authorizing" => 1, "resume" => 4, "artificial" => 7, "meditations" => 4, "dancing" => 20, "scottish" => 4, "scylla" => 1, "phibbus" => 1, "swelling" => 23, "chopfallen" => 1, "complaints" => 9, "seated" => 14, "texpel" => 1, "alwayswindobeying" => 1, "ocean" => 33, "stormy" => 7, "call" => 594, "swifter" => 14, "charles" => 124, "constantly" => 7, "acknowledgment" => 1, "sinnd" => 4, "vloutingstocks" => 1, "grinding" => 3, "strangler" => 1, "dilemma" => 1, "frenchmen" => 13, "940" => 1, "ducat" => 6, "wellnigh" => 3, "ralph" => 3, "fillet" => 2, "deepmouthd" => 3, "galloway" => 1, "choired" => 1, "fleshyou" => 1, "husbandless" => 1, "bracelets" => 3, "london" => 174, "stonestill" => 2, "verefore" => 1, "sith" => 21, "soothsay" => 1, "granted" => 31, "fisherman" => 34, "fencing" => 4, "measurd" => 5, "ensuing" => 11, "pinked" => 1, "conjoins" => 1, "fens" => 2, "ninefold" => 1, "spy" => 28, "stephen" => 7, "labras" => 1, "survives" => 2, "malleable" => 1, "hazelnut" => 1, "sluicd" => 1, "notprithee" => 1, "salving" => 1, "interposes" => 1, "enanmourd" => 1, "dizzyeyd" => 1, "therewhat" => 1, "stretch" => 19, "youre" => 59, "illusion" => 3, "shipmen" => 1, "stinkingly" => 1, "crimeless" => 1, "saddest" => 2, "jennys" => 1, "flatterd" => 4, "hemaster" => 1, "easyyielding" => 1, "fashion" => 101, "prophets" => 5, "friendships" => 3, "mamillius" => 21, "aunt" => 25, "mishap" => 2, "dian" => 21, "surge" => 10, "departst" => 1, "terre" => 1, "bastardly" => 1, "described" => 2, "anhungry" => 1, "stabbing" => 6, "rendered" => 5, "laughst" => 1, "32" => 2, "festinately" => 1, "incessantly" => 1, "frommay" => 1, "apprehensions" => 3, "ahanging" => 1, "pool" => 6, "fartuous" => 1, "stoutness" => 2, "foe" => 74, "unmeriting" => 1, "im" => 14, "ungently" => 3, "roundure" => 1, "imponed" => 2, "wouldbut" => 1, "dreadfully" => 3, "tartars" => 5, "becomesto" => 1, "solicitor" => 2, "hangings" => 4, "indicating" => 2, "champian" => 1, "340" => 1, "waterton" => 1, "gamester" => 8, "sanctuary" => 14, "pluckst" => 1, "moist" => 13, "fightinghark" => 1, "keepdown" => 1, "seymour" => 1, "snuffs" => 1, "goden" => 1, "abominations" => 2, "trusty" => 21, "usèd" => 1, "lasto" => 1, "comment" => 15, "necks" => 12, "pettishness" => 1, "pangs" => 15, "attendance" => 9, "insufficience" => 1, "plagues" => 14, "redeemed" => 3, "speechless" => 15, "requickened" => 1, "thoust" => 3, "advocates" => 1, "mor" => 1, "effigies" => 1, "causeo" => 1, "innkeeper" => 1, "buttery" => 2, "subtler" => 1, "supping" => 1, "ridingrods" => 1, "victorious" => 15, "dere" => 3, "stir" => 87, "congest" => 1, "shrovetuesday" => 1, "shivered" => 1, "theme" => 30, "unguarded" => 3, "lestrale" => 2, "bowstring" => 1, "soundpost" => 1, "palsies" => 1,

# %% [markdown]
# ## Word Histogram
#
# Here is a program that reads a file and builds a histogram of the words in the file:

# %%
function processfile(filename)
    hist = Dict()
    for line in eachline(filename)
        processline(line, hist) 
    end
    hist
end;

function processline(line, hist)
    line = replace(line, '-' => ' ')
    for word in split(line)
        word = string(filter(isletter, [word...])...)
        word = lowercase(word)
        hist[word] = get!(hist, word, 0) + 1
    end
end;

# %%
hist = processfile("emma.txt")
# Out:
# Dict{Any, Any} with 7380 entries:
#   "prejudices"      => 1
#   "practise"        => 3
#   "adviser"         => 1
#   "forbade"         => 1
#   "offend"          => 3
#   "quicksighted"    => 1
#   "contemplate"     => 1
#   "enjoy"           => 9
#   "diffuse"         => 1
#   "unreserved"      => 1
#   "transplantation" => 1
#   "fight"           => 1
#   "dulness"         => 3
#   "everywhere"      => 3
#   "exult"           => 1
#   "indelicacy"      => 1
#   "inattentive"     => 1
#   "helping"         => 1
#   "whose"           => 39
#   ⋮                 => ⋮

# %%
function totalwords(hist)
    sum(values(hist))
end

function differentwords(hist)
    length(hist)
end
# Out:
# differentwords (generic function with 1 method)

# %%
println("Total number of words: ", totalwords( hist))
# Out:
# Total number of words: 162742

# %%
println("Number of different words: ", differentwords(hist))
# Out:
# Number of different words: 7380

# %% [markdown]
# ## Most Common Words
#
# To find the most common words, we can make an array of tuples, where each tuple
# contains a word and its frequency, and sort it. The following function takes a histo‐
# gram and returns an array of word-frequency tuples:

# %%
function mostcommon(hist)
    t = []
    for (key, value) in hist 
        push!(t, (value, key))
    end
    reverse(sort(t))
end
# Out:
# mostcommon (generic function with 1 method)

# %%
t = mostcommon(hist)
println("The most common words are: ")
for (freq, word) in t[1:10] 
    println(word, "\t", freq)
end
# Out:
# The most common words are:
# to	5295
# the	5266
# and	4931
# of	4339
# i	3191
# a	3155
# it	2546
# her	2483
# was	2400
# she	2364

# %% [markdown]
# ## Optional Parameters

# %%
function printmostcommon(hist, num = 10)
    t = mostcommon(hist)
    println("The most common words are: ")
    for (freq, word) in t[1:num] 
        println(word, "\t", freq)
    end
end
# Out:
# printmostcommon (generic function with 2 methods)

# %%
printmostcommon(hist)
# Out:
# The most common words are:
# to	5295
# the	5266
# and	4931
# of	4339
# i	3191
# a	3155
# it	2546
# her	2483
# was	2400
# she	2364

# %%
printmostcommon(hist, 30)
# Out:
# The most common words are:
# to	5295
# the	5266
# and	4931
# of	4339
# i	3191
# a	3155
# it	2546
# her	2483
# was	2400
# she	2364
# in	2199
# not	2161
# you	2053
# be	1987
# he	1811
# that	1809
# had	1626
# but	1446
# as	1443
# for	1371
# have	1328
# is	1261
# with	1222
# very	1212
# mr	1154
# his	1150
# at	1041
# so	979
# all	855
# could	837

# %% [markdown]
# ## Dictionary Subtraction

# %%
function subtract(d1, d2)
    res = Dict()
    for key in keys(d1)
        if key ∉ keys(d2)
            res[key] = nothing
        end
    end
    res
end
# Out:
# subtract (generic function with 1 method)

# %%
words = processfile("words.txt")
# Out:
# Dict{Any, Any} with 113809 entries:
#   "epinaoi"         => 1
#   "nimbused"        => 1
#   "pintoes"         => 1
#   "interties"       => 1
#   "inattentive"     => 1
#   "cliquing"        => 1
#   "photosynthesis"  => 1
#   "sleepwalking"    => 1
#   "chicanes"        => 1
#   "lunk"            => 1
#   "ethmoids"        => 1
#   "reemitted"       => 1
#   "henry"           => 1
#   "hotheadednesses" => 1
#   "planches"        => 1
#   "entomb"          => 1
#   "whiz"            => 1
#   "redresses"       => 1
#   "wormwoods"       => 1
#   ⋮                 => ⋮

# %%
hist
# Out:
# Dict{Any, Any} with 7380 entries:
#   "prejudices"      => 1
#   "practise"        => 3
#   "adviser"         => 1
#   "forbade"         => 1
#   "offend"          => 3
#   "quicksighted"    => 1
#   "contemplate"     => 1
#   "enjoy"           => 9
#   "diffuse"         => 1
#   "unreserved"      => 1
#   "transplantation" => 1
#   "fight"           => 1
#   "dulness"         => 3
#   "everywhere"      => 3
#   "exult"           => 1
#   "indelicacy"      => 1
#   "inattentive"     => 1
#   "helping"         => 1
#   "whose"           => 39
#   ⋮                 => ⋮

# %%
words
# Out:
# Dict{Any, Any} with 113809 entries:
#   "epinaoi"         => 1
#   "nimbused"        => 1
#   "pintoes"         => 1
#   "interties"       => 1
#   "inattentive"     => 1
#   "cliquing"        => 1
#   "photosynthesis"  => 1
#   "sleepwalking"    => 1
#   "chicanes"        => 1
#   "lunk"            => 1
#   "ethmoids"        => 1
#   "reemitted"       => 1
#   "henry"           => 1
#   "hotheadednesses" => 1
#   "planches"        => 1
#   "entomb"          => 1
#   "whiz"            => 1
#   "redresses"       => 1
#   "wormwoods"       => 1
#   ⋮                 => ⋮

# %%
diff = subtract(hist, words)
# Out:
# Dict{Any, Any} with 549 entries:
#   "outree"         => nothing
#   "quicksighted"   => nothing
#   "outwardly"      => nothing
#   "adelaide"       => nothing
#   "jeffereys"      => nothing
#   "unreserved"     => nothing
#   "dixons"         => nothing
#   "betweens"       => nothing
#   "groundless"     => nothing
#   "jamess"         => nothing
#   "westons"        => nothing
#   "remembrance"    => nothing
#   "unsuccessfully" => nothing
#   "hawkinss"       => nothing
#   "rencontre"      => nothing
#   "deservedly"     => nothing
#   "favourably"     => nothing
#   "incommoded"     => nothing
#   "unfavourable"   => nothing
#   ⋮                => ⋮

# %%
println("Words in the book that aren't in the word list: ")
for word in keys(diff)
    print(word, " ")
end
# Out:
# Words in the book that aren't in the word list:
# outree quicksighted outwardly adelaide jeffereys unreserved dixons betweens groundless jamess westons remembrance unsuccessfully hawkinss rencontre deservedly favourably incommoded unfavourable wiltshire bateses recollecting newsletters recollected irresistibly pianoforte undiscerned ungraciously humourist bitnet placidity swisserland il xxxxxxxxx internet prosings constitutions ult christian xvi illinois outstepped november woodhouse experienced favourite neptune ocr wallises companionably tremblings recollect uninterruptedly ing emma smallridges disingenuousness injustice admirably appellation familiarise hartuiucvmd surry ix c ii xiii cromer shakespeare vii unconvinced coxs tranquillised complimenter broadwood bellas goodnatured dont richardson doatingly braithwaites unimpeded michaelmas reanimation endthe neighbourhood william influenced harriets disclaimer churchill twelvemonth tunbridge england gentlemans imaginist unexampled hodges dir apologised grahams etextsverend stimulative a winkd sympathise pressingly asparagus adventuring michael mutterings s novitiate maam administered otway hetty destind kramer beaufet hesitatingly wingfields etextsstart soothings illiberal augusta lieut mickleham  isabella cramer inconsideration suitableness feelingly shant mantelpiece caroline promptitude williams penetrated electronically oclock authorised hartvmdcsouiucedu saturday unconcern tupman fastidious d unbleached embrocation wakefield patriae behindhand elizabeth foolishly grandpapa buyings xix penetrating exultingly mcimail al monday hypertext delightfully brunswick wretchedly windsor benedictine unequalled charles b apologise fairfax observable mitchells langham reprobating december unpersuadable grandmama non harmonise goddard persuadable teazed collation aimable o perrys puppyism humouredly sposo visitings m commandingly improvidently tete london n f goddards pre inferiorities aggrandise sufferable honourable blameable xiv emmas smilingly taylors nobodys churchilld merchantability impartial waverings disengage weston yorkshire secresy excusable email doubtingly etextarticles adair clara unexamined unreserve housebreaking silversmith bickerton mr hawkins gentlemens emmazip patroness ascii complacently disclaimers hughes donwell unmentioned sunday deedily uncouthness sweetbread untouched misunderstood hannah honourably friday mistresss recantation dostalis greatcoat arrowroot etext unsuitable childs amor valetudinarian undesigned confidantes pointedly caro xii disengaged theodore unpretending february neighbour penetrate italian broadwoods remembrances conversable rumination james favourable complaisance arthur hindrance churchills unseasonableness designedly eltons july compuservecom enscombe mens hartfield chuse amiableness baly attmail woodhouses tupmans printfor solitarily tm bragges endeavoured charitable transcribing undesignedly controul holyhead unsentimental inquietudes cultivation serle comtesse october tel apartment austen collectedly birmingham taylor nash chuses unsuspected philippics fancifulness randalls stomacher unpolished iii barnes encumbrance gutenbergibc wallis rationality paradings greensward newgut campbell irish unmirthful june knightley behaviour larkinss ungallant hartfields etextetext rd april bragge thats connexions gentlemanlike th indexgut robert e irksomeness manoeuvring x substance ungracious endeavour heartedness desirableness insignificance delightful transcribed endeavours emmaatxt selinas abruptness astleys solicitously disagreeableness otways genlis crossness viii alderneys abdys elton goodhumoured wonderings l acquirements clifton catherine george slightingly champaign kingston philip aladdins xvii scotland mrs disapprobation adversarys encourager dalmane garricks unceremoniousness heartfelt unobjectionable gutenberg st particularity pembroke ftp unsullied etc bodys unexceptionably iv bella complimented tuesday undistinguishing blockhead ceaseless discomposed ireland yourlogin p incommoding  ...

# %% [markdown]
# ## Exercise 13-6
#
# Write a program that uses set subtraction to find words in the book that are not in the
# word list.

# %%
function subtract2(d1, d2)
    setdiff(d1, d2)
end
# Out:
# subtract2 (generic function with 1 method)

# %%
subtract2(hist, words)
# Out:
# 4782

# %% [markdown]
# ## Random Words
#
# To choose a random word from the histogram, the simplest algorithm is to build an
# array with multiple copies of each word, according to the observed frequency, and
# then choose from the array:

# %%
function randomword(h)
    t = []
    for (word, freq) in h 
        @show word, freq
        for i in 1:freq 
            push!(t, word)
        end
    end
    return rand(t)
end
# Out:
# randomword (generic function with 1 method)

# %%
randomword(words)
# Out:
# "womanliness"

# %%
function randombook(h)
    hist = processfile(h)
    word = randomword(hist)
    return word
end
# Out:
# randombook (generic function with 1 method)

# %%
randombook("Shakespeare.txt")
# Out:
# "you"
